# %%
# %matplotlib inline

# %%
from utils import list_images
from imagelabeler import SimpleImageLabaler
lab = SimpleImageLabaler('/home/i008/googledrive/Projects/pyimagegurus/data/4scenes/', 
                         preload_labels=False,
                        label_options=['A','B','C','D'])
lab.start()
# Out:
# [INFO] Resuming at index 0

# %%
import numpy as np

# %%
np.expand_dims(np.expand_dims(np.array([1,2,3,4]).reshape(2,2), axis=0), axis=0)[0][0][:, 1]
# Out:
# array([2, 4])
